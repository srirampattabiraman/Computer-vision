# %%
# let's mount our google drive
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········

# %%
import pandas as pd
import json

# %%
j_file = open('/content/drive/My Drive/s12/annotation/via_export_coco.json')
j_data = json.loads(j_file.read())
j_file.close()

# %%
dog_df = pd.DataFrame()

# %%
j_data
# Out:
# {'annotations': [{'area': 251706,
#    'bbox': [21, 42, 461, 546],
#    'id': 0,
#    'image_id': '0',
#    'iscrowd': 0,
#    'segmentation': [21, 42, 482, 42, 482, 588, 21, 588]},
#   {'area': 326560,
#    'bbox': [65, 76, 416, 785],
#    'id': 1,
#    'image_id': '1',
#    'iscrowd': 0,
#    'segmentation': [65, 76, 481, 76, 481, 861, 65, 861]},
#   {'area': 310968,
#    'bbox': [46, 50, 617, 504],
#    'id': 2,
#    'image_id': '2',
#    'iscrowd': 0,
#    'segmentation': [46, 50, 663, 50, 663, 554, 46, 554]},
#   {'area': 1732024,
#    'bbox': [269, 38, 1576, 1099],
#    'id': 3,
#    'image_id': '3',
#    'iscrowd': 0,
#    'segmentation': [269, 38, 1845, 38, 1845, 1137, 269, 1137]},
#   {'area': 304440,
#    'bbox': [812, 32, 590, 516],
#    'id': 4,
#    'image_id': '4',
#    'iscrowd': 0,
#    'segmentation': [812, 32, 1402, 32, 1402, 548, 812, 548]},
#   {'area': 71600,
#    'bbox': [82, 45, 358, 200],
#    'id': 5,
#    'image_id': '5',
#    'iscrowd': 0,
# ...
